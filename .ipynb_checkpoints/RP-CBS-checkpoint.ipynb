# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import networkx as nx
import community
# %matplotlib inline

# %%
f = open('cbs.output.txt')

events = []

for line in f:
    #print line
    contents = line.split()
    #print contents
    events.append([int(contents[0])-1,int(contents[1])-1])

f.close()

# %%
len(events)
# Out:
# 10979583

# %%
users = []
machines = []
for event in events:
    users.append(event[0])
    machines.append(event[1])

# %%
N = max(users)+1
M = max(machines)+1
access = np.array([[0.0 for j in xrange(M+1)] for i in xrange(N+1)])

print N, M
# Out:
# 3931 21

# %%
for event in events:
    access[event[0],event[1]] += 1

# %%
access
# Out:
# matrix([[  2.26025000e+05,   3.17700000e+03,   2.84500000e+03, ...,
#            4.00800000e+03,   3.00000000e+01,   0.00000000e+00],
#         [  3.70850000e+05,   2.98685000e+05,   2.21202000e+05, ...,
#            3.44417000e+05,   3.35157000e+05,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         ...,
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00]])

# %%
for i in xrange(N+1):
    temp = np.sum(access[i,:-1])
    access[i,M] = temp

for j in xrange(M+1):
    access[N,j] = np.sum(access[:-1,j])

# %%
access
# Out:
# matrix([[  2.26025000e+05,   3.17700000e+03,   2.84500000e+03, ...,
#            4.00800000e+03,   3.00000000e+01,   4.57715000e+05],
#         [  3.70850000e+05,   2.98685000e+05,   2.21202000e+05, ...,
#            3.44417000e+05,   3.35157000e+05,   6.37423800e+06],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   3.09718000e+05],
#         ...,
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   1.00000000e+00],
#         [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   8.00000000e+00],
#         [  6.84392000e+05,   4.52689000e+05,   4.66246000e+05, ...,
#            4.61371000e+05,   4.25387000e+05,   1.09795830e+07]])

# %%
for u in xrange(N):
    if access[u,M] == 0:
        access[u,M] = -1
        
for m in xrange(M):
    if access[N,m] == 0:
        access[N,m] = -1

# %%
profile_u = np.array([[0.0 for j in xrange(M)] for i in xrange(N)])
for u in xrange(N):
    for m in xrange(M):
        profile_u[u,m] = access[u,m]/access[u,M]
        
profile_m = np.array([[0.0 for j in xrange(M)] for i in xrange(N)])
for u in xrange(N):
    for m in xrange(M):
        profile_m[u,m] = access[u,m]/access[N,m]

# %%
RP = np.matrix([[0.0 for j in xrange(N)] for i in xrange(N)])

vals = []
for u in xrange(N):
    for v in xrange(N):
        val = np.dot(profile_u[u], profile_m[v])
        RP[u,v] = val
        vals.append(val)

# %%
RP
# Out:
# matrix([[  1.95987119e-01,   4.78127050e-01,   4.88932514e-02, ...,
#            9.06110379e-07,   2.86294408e-08,   1.90367908e-07],
#         [  3.43328760e-02,   6.38332880e-01,   9.47561611e-03, ...,
#            8.32475815e-06,   1.06376190e-07,   9.70150761e-07],
#         [  7.22566159e-02,   1.95015570e-01,   2.92056113e-01, ...,
#            0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#         ...,
#         [  5.92486160e-03,   7.58056997e-01,   0.00000000e+00, ...,
#            7.90707632e-05,   0.00000000e+00,   0.00000000e+00],
#         [  1.31041245e-02,   6.78067153e-01,   0.00000000e+00, ...,
#            0.00000000e+00,   2.19352603e-06,   0.00000000e+00],
#         [  1.08917809e-02,   7.72996480e-01,   0.00000000e+00, ...,
#            0.00000000e+00,   0.00000000e+00,   1.74129191e-05]])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(vals,20)
# Out:
# (array([  1.54408970e+07,   5.00200000e+03,   9.11000000e+02,
#           4.89000000e+02,   4.17000000e+02,   8.53000000e+02,
#           3.58000000e+02,   3.19000000e+02,   3.51000000e+02,
#           1.01000000e+02,   8.40000000e+02,   5.01000000e+02,
#           3.02000000e+02,   1.38000000e+02,   1.22000000e+02,
#           2.04000000e+02,   3.54000000e+02,   2.17000000e+02,
#           2.34000000e+02,   1.51000000e+02]),
#  array([ 0.        ,  0.04101347,  0.08202694,  0.12304041,  0.16405388,
#          0.20506735,  0.24608082,  0.2870943 ,  0.32810777,  0.36912124,
#          0.41013471,  0.45114818,  0.49216165,  0.53317512,  0.57418859,
#          0.61520206,  0.65621553,  0.697229  ,  0.73824247,  0.77925595,
#          0.82026942]),
#  <a list of 20 Patch objects>)

# %%
labels = [-1 for u in xrange(N)]

new = 0
for u in xrange(N):
    if labels[u]==-1:
        labels[u] = new
        new += 1
    for v in xrange(u+1,N):
        if RP[u,v]>=0.05:
            labels[v] = labels[u]
            
max(labels)+1
# Out:
# 3922

# %%
G = nx.Graph()

for u in xrange(N):
    for v in xrange(u+1,N):
        G.add_weighted_edges_from([(u,v,RP[u,v])])

# %%
partition = community.best_partition(G)

# %%
size = float(len(set(partition.values())))
pos = nx.spring_layout(G)
count = 0.
for com in set(partition.values()) :
    count = count + 1.
    list_nodes = [nodes for nodes in partition.keys()
                                if partition[nodes] == com]
    nx.draw_networkx_nodes(G, pos, list_nodes, node_size = 20,
                                node_color = str(count / size))


nx.draw_networkx_edges(G,pos, alpha=0.5)

# %%
g = 0
for u in xrange(N):
    if g<partition[u]:
        g = partition[u]
        
g+1
# Out:
# 6
